# %% [markdown]
# ### Parte 1: Numpy

# %%
import numpy as np

# %% [markdown]
# #### 1) ¿Cuál es el tamaño en bytes de un arrray de 1000 elementos de tipo booleano?

# %%
ABooleano = np.arange(0,1000,1)

# %% [markdown]
# #### Tamaño de un array booleano de 1000 items

# %%
ABolean = ABooleano == 2
print(ABolean.itemsize)
# Out:
# 1

# %% [markdown]
# #### Tamaño de un array con 10000 numero enteros

# %%
print(ABooleano.itemsize)
# Out:
# 4

# %% [markdown]
# #### 2) Cree un array cuyos elementos sean los enteros pares en [1,100] y en orden decreciente. Muestre los 10 últimos por pantalla.

# %%
decre = np.arange(100,1,-2)
decre[-10:]
# Out:
# array([20, 18, 16, 14, 12, 10,  8,  6,  4,  2])

# %% [markdown]
# #### 3) Dado el array
# ##### 2 4 5 6
# ##### 0 3 7 4
# ##### 8 8 5 2
# ##### 1 5 6 1
#
# Seleccione con una instrucción el subarray de elementos 0 3 7 4

# %%
Array = np.array([[2,4,5,6],[0,3,7,4],[8,8,5,2],[1,5,6,1]])
Array[1]
# Out:
# array([0, 3, 7, 4])

# %% [markdown]
# #### Después, seleccione el subarray de elementos
# ##### 2 5
# ##### 8 5

# %%
np.array([[Array[0,0], Array[0,2]],[Array[2,0], Array[2,2]]])
# Out:
# array([[2, 5],
#        [8, 5]])

# %% [markdown]
# #### 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9], obtenga la media aritmética de la diferencia (a-b).

# %%
a = np.array([1,4,2,7])
b = np.array([1,3,2,9])

np.mean(a-b)
# Out:
# -0.25

# %% [markdown]
# #### 5) Tengo valores de cordenadas (x, y) en las columnas del array
# ##### 1.33 4.5
# ##### 30.0 10.7
# ##### 70.2 0.5

# %%
eje5 = np.array([[1.33,4.5],[30.0,10.7],[70.2,0.5]])
eje5
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ]])

# %%
c= np.append(eje5, [[37.1,-3.6]], axis=0)
c
# Out:
# array([[ 1.33,  4.5 ],
#        [30.  , 10.7 ],
#        [70.2 ,  0.5 ],
#        [37.1 , -3.6 ]])

# %% [markdown]
# #### 6) Copie el array del ejercicio anterior. Traspóngalo (.Agregue ahora dos nuevos pares de coordenadas: (10.8, 3.0) y (35.8, 12.0).

# %%
d= np.append(c, [[10.8,3.0],[35.8,12.0]], axis=0)
np.reshape(d,(2,6))
# Out:
# array([[ 1.33,  4.5 , 30.  , 10.7 , 70.2 ,  0.5 ],
#        [37.1 , -3.6 , 10.8 ,  3.  , 35.8 , 12.  ]])

# %% [markdown]
# #### Parte 2: Exploaración y Minería de Datos

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
filename = 'NucleosPoblacion.csv'
raw_data = open(filename)
data = pd.read_csv(filename, header=0)

print(data.shape)
print (data.head(10))
# Out:
# (852, 10)
#    FID  OBJECTID                       Texto  Poblacion  CodMun  \
# 0    0         1                     Agüimes    29431.0   35002
# 1    1         2                     Antigua    10458.0   35003
# 2    2         3                    Arrecife    58156.0   35004
# 3    3         4                      Arucas    36745.0   35006
# 4    4         5                      Gáldar    24473.0   35009
# 5    5         6                     Ingenio    29640.0   35011
# 6    6         7                       Mogán    22638.0   35012
# 7    7         8                    La Oliva    22351.0   35014
# 8    8         9                      Pájara    20622.0   35015
# 9    9        10  Las Palmas de Gran Canaria   383308.0   35016
#
#                     Municipio  CodProvin   Provincia          X          Y
# 0                     Agüimes         35  Las Palmas -15.446012  27.900542
# 1                     Antigua         35  Las Palmas -14.013301  28.418966
# ...

# %% [markdown]
# #### 1) ¿Cuántos Municipios tienen más de 100000 habitantes?.

# %%
datos = data[data['Poblacion'] >=10000]

MunUnicos = np.count_nonzero( np.unique(datos.Municipio))

MunUnicos
# Out:
# 751

# %% [markdown]
# #### 2) Realice una gráfica de barras sobre la polbación de cada ciudad, ordenela de menor a mayor y responda:

# %% [markdown]
# #### a. ¿Cuál es la segunda ciudad más poblada?

# %%
datos= data.sort_values('Poblacion', ascending= False)

color= ['']
plt.bar(datos['Texto'],datos['Poblacion'],color ="purple")
plt.title("Grafica de barras de ciudades vs población ")
plt.xlabel("Ciudades")
plt.ylabel("Población")
# Out:
# Text(0, 0.5, 'Población')

# %%
dd = np.array(datos)
dd[-2,2]
# Out:
# 'Barcelona'

# %% [markdown]
# #### b. ¿Qué posición ocupa Granada en el ranking de las ciudades más pobladas?

# %%
datos2= datos.sort_values('Poblacion', ascending= False)
datos2
# Out:
#      FID  OBJECTID           Texto  Poblacion  CodMun       Municipio  \
# 355  355       356          Madrid  3273049.0   28079          Madrid
# 623  623       624       Barcelona  1619337.0    8019       Barcelona
# 561  561       562        Valencia   809267.0   46250        Valencia
# 492  492       493         Sevilla   704198.0   41091         Sevilla
# 591  591       592        Zaragoza   675121.0   50297        Zaragoza
# ..   ...       ...             ...        ...     ...             ...
# 525  525       526           Buñol    10077.0   46077           Buñol
# 746  746       747  Premià de Dalt    10064.0    8230  Premià de Dalt
# 168  168       169         Amurrio    10050.0    1002         Amurrio
# 115  115       116  Caldas de Reis    10045.0   36005  Caldas de Reis
# 307  307       308       Zumarraga    10037.0   20080       Zumarraga
#
#      CodProvin          Provincia         X          Y
# 355         28             Madrid -3.703797  40.416630
# ...

# %%
ciudades = datos2['Texto']
ciudades2 = ciudades.reset_index()
ciudades2
# Out:
#      index           Texto
# 0      355          Madrid
# 1      623       Barcelona
# 2      561        Valencia
# 3      492         Sevilla
# 4      591        Zaragoza
# ..     ...             ...
# 847    525           Buñol
# 848    746  Premià de Dalt
# 849    168         Amurrio
# 850    115  Caldas de Reis
# 851    307       Zumarraga
#
# [852 rows x 2 columns]

# %%
ciudades2[(ciudades2['Texto']=='Granada')]
# Out:
#     index    Texto
# 17    272  Granada

# %% [markdown]
# #### R/posición  18 contando del 1 y posición 17 contando desde 0

# %% [markdown]
# #### 3) ¿Cuántos municipios de Extremadura tienen más de 5000 habitantes?.

# %%
datos2[(datos2['Provincia']=='Málaga') & (datos2['Poblacion']>5000)].reset_index()
# Out:
#     index  FID  OBJECTID                                Texto  Poblacion  \
# 0     391  391       392                               Málaga   568507.0
# 1     393  393       394                             Marbella   136322.0
# 2     394  394       395                                Mijas    76362.0
# 3     399  399       400                         Vélez-Málaga    75623.0
# 4     390  390       391                           Fuengirola    71783.0
# 5     400  400       401                         Torremolinos    66957.0
# 6     389  389       390                             Estepona    66150.0
# 7     386  386       387                          Benalmádena    61383.0
# 8     787  787       788  Arroyo de la Miel-Benalmadena Costa    52061.0
# 9     385  385       386                            Antequera    45234.0
# 10    793  793       794                          Las Lagunas    41299.0
# 11    396  396       397                Rincón de la Victoria    39922.0
# ...

# %% [markdown]
# #### 4) ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
datos3= datos.sort_values('Y', ascending= False)
nuevo = np.array(datos3)
np.array([nuevo[0,9], nuevo[0,7],nuevo[0,3]])

#print(np.max(datos3.Y))
# Out:
# array(['43.6255783851', 'Lugo', '16211.0'], dtype='<U32')

# %%
datos3
# Out:
#      FID  OBJECTID             Texto  Poblacion  CodMun  \
# 104  104       105           Viveiro    16211.0   27066
# 447  447       448    Lluanco/Luanco    10788.0   33025
# 443  443       444            Candás    11000.0   33014
# 444  444       445    Piedrasblancas    22832.0   33016
# 442  442       443            Avilés    84202.0   33004
# ..   ...       ...               ...        ...     ...
# 6      6         7             Mogán    22638.0   35012
# 758  758       759  Cruce de Sardina    24514.0   35022
# 760  760       761        Vecindario    11583.0   35022
# 759  759       760       El Doctoral    15012.0   35022
# 757  757       758      San Fernando    18823.0   35019
#
#                      Municipio  CodProvin   Provincia          X          Y
# 104                    Viveiro         27        Lugo  -7.588768  43.625578
# 447                      Gozón         33    Asturias  -5.792773  43.614030
# ...

# %% [markdown]
# #### 5) Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada

# %%
Granada = datos3[(datos3['Provincia']=='Granada')]
media = np.mean(Granada.Poblacion)
mediana = np.median(Granada.Poblacion)
desv = np.std(Granada.Poblacion)
maximo = np.max(Granada.Poblacion)
minimo = np.min(Granada.Poblacion)
media, mediana, desv, maximo, minimo
# Out:
# (30217.85, 17526.0, 49080.462187386736, 239154.0, 10386.0)

# %% [markdown]
# #### 6) Realice un histograma con la población de los Municipios para cada una de las provincias.

# %%
Grupo_Provincias = datos3.groupby('Provincia')
GP= Grupo_Provincias.sum()
# Out:
# C:\Users\haroldo.marroquin\AppData\Local\Temp\ipykernel_14004\3639540942.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   GP= Grupo_Provincias.sum()

# %% [markdown]
# #### 7)

# %%
MunUnicos2 =  np.unique(datos.Municipio )
MunUnicos2
# Out:
# array(['A Coruña', 'A Estrada', 'A Guarda', 'A Laracha', 'Abarán',
#        'Abrera', 'Adeje', 'Adra', 'Aguilar de la Frontera', 'Agüimes',
#        'Alacant/Alicante', 'Alaquàs', 'Albacete', 'Albal', 'Albatera',
#        'Alberic', 'Albolote', 'Alboraya', 'Albox', 'Alcalá de Guadaíra',
#        'Alcalá de Henares', 'Alcalá del Río', 'Alcalá la Real', 'Alcanar',
#        'Alcantarilla', 'Alcaudete', 'Alcañiz', 'Alcobendas', 'Alcorcón',
#        'Alcoy/Alcoi', 'Alcázar de San Juan', 'Alcúdia', 'Aldaia',
#        'Alfafar', 'Algeciras', 'Algemesí', 'Algete', 'Alginet',
#        'Alhama de Murcia', 'Alhaurín de la Torre', 'Alhaurín el Grande',
#        'Aljaraque', 'Aller', 'Almansa', 'Almazora/Almassora',
#        'Almendralejo', 'Almería', 'Almonte', 'Almoradí', 'Almuñécar',
#        'Alovera', 'Alpedrete', 'Altea', 'Alzira', 'Ames',
#        'Amorebieta-Etxano', 'Amposta', 'Amurrio', 'Andoain', 'Andratx',
#        'Andújar', 'Ansoáin/Antsoain', 'Antequera', 'Antigua', 'Arahal',
# ...

# %%
import random

# %%
for i in range(50):
     print(random.choice(MunUnicos2))
# Out:
# Arteixo
# Cunit
# Santoña
# Montilla
# Vilassar de Mar
# San Pedro del Pinatar
# Chiva
# Boiro
# Murcia
# A Estrada
# Gines
# Alhama de Murcia
# Salt
# Calahorra
# Barcelona
# Chiclana de la Frontera
# Meco
# Arucas
# Coria del Río
# Mancha Real
# Santa Pola
# Baeza
# Mérida
# Leioa
# Canovelles
# Langreo
# Tortosa
# Alhaurín de la Torre
# Elgoibar
# Pontevedra
# Puertollano
# Laviana
# Vilanova de Arousa
# Cártama
# Arahal
# Mancha Real
# San Lorenzo de El Escorial
# Salobreña
# Riba-roja de Túria
# Maracena
# Marbella
# Montcada i Reixac
# La Solana
# San Bartolomé de Tirajana
# Majadahonda
# Manacor
# Callosa de Segura
# Vícar
# La Solana
# Murcia
